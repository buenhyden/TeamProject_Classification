# %%
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
dfTrain = pd.read_csv('./data/act_train.csv')
dfPeople = pd.read_csv('./data/people.csv')
dfTest = pd.read_csv('./data/act_test.csv')

# %%
print (dfTrain.shape)
print (dfPeople.shape)
# Out:
# (2197291, 15)
# (189118, 41)

# %%
df = pd.DataFrame(dfTrain.people_id.value_counts().reset_index())

# %%
df.columns = ['people_id', 'count']
df.tail()
# Out:
#          people_id  count
# 151290   ppl_93121      1
# 151291  ppl_169362      1
# 151292  ppl_365377      1
# 151293  ppl_336762      1
# 151294  ppl_133042      1

# %%
merged = pd.merge(dfPeople, df, on = 'people_id')
merged.tail()
# Out:
#         people_id  char_1      group_1  char_2        date  char_3  char_4  \
# 151290  ppl_99981  type 2  group 17304  type 2  2023-01-26  type 5  type 5
# 151291  ppl_99987  type 1   group 8600  type 1  2022-04-02  type 4  type 6
# 151292   ppl_9999  type 2  group 17304  type 2  2023-02-23  type 6  type 2
# 151293  ppl_99992  type 2  group 17304  type 2  2020-06-25  type 5  type 5
# 151294  ppl_99994  type 2  group 17764  type 3  2023-01-06  type 2  type 7
#
#         char_5  char_6   char_7  ...   char_30 char_31  char_32  char_33  \
# 151290  type 5  type 2   type 5  ...     False   False     True    False
# 151291  type 4  type 3  type 11  ...     False   False     True    False
# 151292  type 8  type 3  type 11  ...     False   False    False    False
# 151293  type 3  type 4  type 16  ...     False   False    False    False
# 151294  type 2  type 1   type 2  ...      True    True     True    False
#
#         char_34  char_35  char_36  char_37  char_38  count
# ...

# %%
dfTrain.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2197291 entries, 0 to 2197290
# Data columns (total 15 columns):
# people_id            object
# activity_id          object
# date                 object
# activity_category    object
# char_1               object
# char_2               object
# char_3               object
# char_4               object
# char_5               object
# char_6               object
# char_7               object
# char_8               object
# char_9               object
# char_10              object
# outcome              int64
# dtypes: int64(1), object(14)
# memory usage: 251.5+ MB

# %%
x = dfTrain.groupby(['activity_category','outcome'])

# %%
ac_count = pd.crosstab(dfTrain['activity_category'],dfTrain['outcome'],dropna=False)

# %%
ac_count.plot(kind = 'bar',stacked=True)
# Out:
# /Users/hyunyoun/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['nanumgothic'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
c1_count = pd.crosstab(dfTrain['char_1'],dfTrain['outcome'],dropna=False)
plt.figure(figsize=(7,7))
c1_count.plot(kind = 'bar', stacked=True)
# Out:
# /Users/hyunyoun/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['nanumgothic'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
c2_count = pd.crosstab(dfTrain['char_2'],dfTrain['outcome'],dropna=False)
plt.figure(figsize=(7,7))
c2_count.plot(kind = 'bar', stacked=True)
# Out:
# /Users/hyunyoun/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['nanumgothic'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
c3_count = pd.crosstab(dfTrain['char_3'],dfTrain['outcome'],dropna=False)
plt.figure(figsize=(7,7))
c3_count.plot(kind = 'bar', stacked=True)
# Out:
# /Users/hyunyoun/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['nanumgothic'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
c4_count = pd.crosstab(dfTrain['char_4'],dfTrain['outcome'],dropna=False)
plt.figure(figsize=(7,7))
c4_count.plot(kind = 'bar', stacked=True)
# Out:
# /Users/hyunyoun/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['nanumgothic'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
c5_count = pd.crosstab(dfTrain['char_5'],dfTrain['outcome'],dropna=False)
plt.figure(figsize=(7,7))
c5_count.plot(kind = 'bar', stacked=True)
# Out:
# /Users/hyunyoun/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['nanumgothic'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
c6_count = pd.crosstab(dfTrain['char_6'],dfTrain['outcome'],dropna=False)
plt.figure(figsize=(7,7))
c6_count.plot(kind = 'bar', stacked=True)
# Out:
# /Users/hyunyoun/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['nanumgothic'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
c7_count = pd.crosstab(dfTrain['char_7'],dfTrain['outcome'],dropna=False)
plt.figure(figsize=(7,7))
c7_count.plot(kind = 'bar', stacked=True)
# Out:
# /Users/hyunyoun/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['nanumgothic'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
c8_count = pd.crosstab(dfTrain['char_8'],dfTrain['outcome'],dropna=False)
plt.figure(figsize=(7,7))
c8_count.plot(kind = 'bar', stacked=True)
# Out:
# /Users/hyunyoun/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['nanumgothic'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
c9_count = pd.crosstab(dfTrain['char_9'],dfTrain['outcome'],dropna=False)
plt.figure(figsize=(7,7))
c9_count.plot(kind = 'bar', stacked=True)
# Out:
# /Users/hyunyoun/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['nanumgothic'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
c10_count = pd.crosstab(dfTrain['char_10'],dfTrain['outcome'],dropna=False)
plt.figure(figsize=(7,7))
c10_count.plot(kind = 'bar', stacked=True)
# Out:
# /Users/hyunyoun/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['nanumgothic'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
dfTrain[dfTrain['people_id']=='ppl_370270'].groupby('activity_category')

# %%
dfPeople.isnull().sum(axis = 0).reset_index()
# Out:
#         index  0
# 0   people_id  0
# 1      char_1  0
# 2     group_1  0
# 3      char_2  0
# 4        date  0
# 5      char_3  0
# 6      char_4  0
# 7      char_5  0
# 8      char_6  0
# 9      char_7  0
# 10     char_8  0
# 11     char_9  0
# 12    char_10  0
# 13    char_11  0
# 14    char_12  0
# 15    char_13  0
# 16    char_14  0
# 17    char_15  0
# 18    char_16  0
# 19    char_17  0
# 20    char_18  0
# 21    char_19  0
# 22    char_20  0
# 23    char_21  0
# 24    char_22  0
# 25    char_23  0
# 26    char_24  0
# 27    char_25  0
# 28    char_26  0
# 29    char_27  0
# 30    char_28  0
# 31    char_29  0
# 32    char_30  0
# 33    char_31  0
# 34    char_32  0
# 35    char_33  0
# 36    char_34  0
# 37    char_35  0
# 38    char_36  0
# 39    char_37  0
# 40    char_38  0

# %%
dfTrain.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2197291 entries, 0 to 2197290
# Data columns (total 15 columns):
# people_id            object
# activity_id          object
# date                 object
# activity_category    object
# char_1               object
# char_2               object
# char_3               object
# char_4               object
# char_5               object
# char_6               object
# char_7               object
# char_8               object
# char_9               object
# char_10              object
# outcome              int64
# dtypes: int64(1), object(14)
# memory usage: 251.5+ MB

# %%
dfTrain.head()
# Out:
#   people_id   activity_id        date activity_category char_1 char_2 char_3  \
# 0   ppl_100  act2_1734928  2023-08-26            type 4    NaN    NaN    NaN
# 1   ppl_100  act2_2434093  2022-09-27            type 2    NaN    NaN    NaN
# 2   ppl_100  act2_3404049  2022-09-27            type 2    NaN    NaN    NaN
# 3   ppl_100  act2_3651215  2023-08-04            type 2    NaN    NaN    NaN
# 4   ppl_100  act2_4109017  2023-08-26            type 2    NaN    NaN    NaN
#
#   char_4 char_5 char_6 char_7 char_8 char_9  char_10  outcome
# 0    NaN    NaN    NaN    NaN    NaN    NaN  type 76        0
# 1    NaN    NaN    NaN    NaN    NaN    NaN   type 1        0
# 2    NaN    NaN    NaN    NaN    NaN    NaN   type 1        0
# 3    NaN    NaN    NaN    NaN    NaN    NaN   type 1        0
# 4    NaN    NaN    NaN    NaN    NaN    NaN   type 1        0

# %%
dfTrain['act']=dfTrain.activity_id.str.split('_').str[0]
dfTrain['act_Number']=dfTrain.activity_id.str.split('_').str[1]

# %%
dfTrain.groupby(['people_id']).count()
# Out:
#             activity_id  date  activity_category  char_1  char_2  char_3  \
# people_id
# ppl_100               6     6                  6       0       0       0
# ppl_100002            2     2                  2       0       0       0
# ppl_100003           34    34                 34       0       0       0
# ppl_100006            3     3                  3       0       0       0
# ppl_100013            5     5                  5       0       0       0
# ppl_100019            2     2                  2       0       0       0
# ppl_100025           46    46                 46       1       1       1
# ppl_100028            3     3                  3       0       0       0
# ppl_100029            1     1                  1       0       0       0
# ppl_100032            3     3                  3       0       0       0
# ppl_100033           19    19                 19       4       4       4
# ppl_100035           54    54                 54       7       7       7
# ...

# %%
dfTrain.groupby(['act','act_Number'])['people_id'].count()
# Out:
# act   act_Number
# act1  100           1
#       100001        1
#       100005        1
#       100008        1
#       100011        1
#       100012        1
#       100014        1
#       100017        1
#       100018        1
#       100019        1
#       10002         1
#       100020        1
#       100022        1
#       100024        1
#       100026        1
#       100027        1
#       10003         1
#       100031        1
#       100032        1
#       100034        1
#       100036        1
#       100037        1
#       100039        1
#       100041        1
#       100042        1
#       100044        1
#       100046        1
#       100056        1
#       100057        1
#       100058        1
#                    ..
# act2  999937        1
#       999939        1
#       99994         1
#       999940        1
#       999942        1
#       999943        1
#       999944        1
#       999947        1
#       999951        1
# ...

# %%
dfTrain.apply(lambda x:x.activity_id.split('_'))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-48-5b22a7c9705b> in <module>()
# ----> 1 dfTrain.apply(lambda x:x.activity_id.split('_'))
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in apply(self, func, axis, broadcast, raw, reduce, args, **kwds)
#    4260                         f, axis,
#    4261                         reduce=reduce,
# -> 4262                         ignore_failures=ignore_failures)
#    4263             else:
#    4264                 return self._apply_broadcast(f, axis)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _apply_standard(self, func, axis, ignore_failures, reduce)
#    4356             try:
#    4357                 for i, v in enumerate(series_gen):
# -> 4358                     results[i] = func(v)
#    4359                     keys.append(v.name)
# ...

# %%
dfPeople.head()
# Out:
#     people_id  char_1      group_1  char_2        date   char_3   char_4  \
# 0     ppl_100  type 2  group 17304  type 2  2021-06-29   type 5   type 5
# 1  ppl_100002  type 2   group 8688  type 3  2021-01-06  type 28   type 9
# 2  ppl_100003  type 2  group 33592  type 3  2022-06-10   type 4   type 8
# 3  ppl_100004  type 2  group 22593  type 3  2022-07-20  type 40  type 25
# 4  ppl_100006  type 2   group 6534  type 3  2022-07-27  type 40  type 25
#
#    char_5  char_6   char_7   ...    char_29 char_30  char_31  char_32  \
# 0  type 5  type 3  type 11   ...      False    True     True    False
# 1  type 5  type 3  type 11   ...      False    True     True     True
# 2  type 5  type 2   type 5   ...      False   False     True     True
# 3  type 9  type 4  type 16   ...       True    True     True     True
# 4  type 9  type 3   type 8   ...      False   False     True    False
#
#    char_33  char_34  char_35  char_36  char_37  char_38
# ...

# %%
dfPeople.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 